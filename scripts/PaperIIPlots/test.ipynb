# %%
import pygmt
import xarray as xr
import rioxarray as rxr 
import pandas as pd
import numpy as np
fig = pygmt.Figure()
# grid = pygmt.datasets.load_earth_relief(
#     resolution="01s", region=[14, 16.25,36.25, 38], registration="gridline")
pygmt.makecpt(cmap="gray", series=[-4500, 500])
fig.grdimage(grid=grid, frame="a", projection="M10c", cmap=True,shading=True)
fig.grdcontour(grid=grid, levels=1,limit=[-0.5, 0.5],annotation=False)
fig.text(position="TL",text="Sicily", font="12p,Helvetica-Bold,black")
fig.text(position="TL",text="Ionian Sea", font="12p,Helvetica-Bold,black",offset="0/-0.5")
fig.show()
