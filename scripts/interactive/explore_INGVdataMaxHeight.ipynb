# %% [markdown]
# What are the files for each event?

# %%
import pandas as pd
import numpy as np
import os
import glob
import xarray as xr
import matplotlib.pyplot as plt
import matplotlib
import matplotlib.dates as mdates


#read list of events from txt file
eve = np.loadtxt('./../../data/events/sample_events53550.txt',dtype = 'str')
sim_dir = './../../data/simu/'
eve_row = 1 #starts from 0
#read the file in one of the sim event folder
eve_path = os.path.join(sim_dir,eve[eve_row])
file_list = glob.glob(eve_path + '/*.nc')
print(*file_list,sep = "\n")
print('')
file_list.sort()
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-lk6wmchy because the default path (/home/naveen.raguramalinga/.config/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_deformation.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_flowdepth.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_flowdepth.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/grid0_ts.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_deformation.nc

# %% [markdown]
# sorting and listing the variables stored in the netcdf files

# %%
print(*file_list,sep = "\n") 
print('')
print(eve[eve_row])

for i in range(len(file_list)):
    print(file_list[i])
    ds = xr.open_dataset(file_list[i])
    print(ds)

#read the file in one of the sim event folder
# Out:
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_deformation.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_flowdepth.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_deformation.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_flowdepth.nc
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/grid0_ts.nc
#
# PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_deformation.nc
# <xarray.Dataset>
# Dimensions:      (x: 912, y: 2224)
# Coordinates:
#   * x            (x) float64 15.02 15.02 15.02 15.02 ... 15.12 15.13 15.13 15.13
#   * y            (y) float64 37.31 37.31 37.31 37.31 ... 37.51 37.51 37.51 37.51
# Data variables:
#     deformation  (y, x) float32 ...
# Attributes:
#     Conventions:  COARDS, CF-1.5
#     title:        Produced by grdconvert
#     history:      grdconvert C_CT.nc?deformation CT_deformation.nc -V\n\t(old...
#     description:
#     GMT_version:  5.4.2 (r18461) [64-bit]
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/CT_flowdepth.nc
# <xarray.Dataset>
# Dimensions:  (lon: 912, lat: 2224)
# Coordinates:
#   * lon      (lon) float64 15.02 15.02 15.02 15.02 ... 15.12 15.13 15.13 15.13
#   * lat      (lat) float64 37.31 37.31 37.31 37.31 ... 37.51 37.51 37.51 37.51
# Data variables:
#     z        (lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS, CF-1.5
#     title:        Produced by grdmath
#     history:      grdmath CT_hmax.nc mask.grd SUB = CT_flowdepth.nc -V
#     description:
#     GMT_version:  5.4.2 (r18461) [64-bit]
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_deformation.nc
# <xarray.Dataset>
# Dimensions:      (x: 1300, y: 948)
# Coordinates:
#   * x            (x) float64 15.2 15.2 15.2 15.2 ... 15.34 15.34 15.34 15.34
#   * y            (y) float64 37.0 37.0 37.0 37.0 ... 37.08 37.08 37.08 37.08
# Data variables:
#     deformation  (y, x) float32 ...
# Attributes:
#     Conventions:  COARDS, CF-1.5
#     title:        Produced by grdconvert
#     history:      grdconvert C_SR.nc?deformation SR_deformation.nc -V\n\t(old...
#     description:
#     GMT_version:  5.4.2 (r18461) [64-bit]
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/SR_flowdepth.nc
# <xarray.Dataset>
# Dimensions:  (lon: 1300, lat: 948)
# Coordinates:
#   * lon      (lon) float64 15.2 15.2 15.2 15.2 15.2 ... 15.34 15.34 15.34 15.34
#   * lat      (lat) float64 37.0 37.0 37.0 37.0 37.0 ... 37.08 37.08 37.08 37.08
# Data variables:
#     z        (lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS, CF-1.5
#     title:        Produced by grdmath
#     history:      grdmath SR_hmax.nc mask.grd SUB = SR_flowdepth.nc -V
#     description:
#     GMT_version:  5.4.2 (r18461) [64-bit]
# ./../../data/simu/PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000/grid0_ts.nc
# <xarray.Dataset>
# Dimensions:         (grid_npoints: 87, time: 481)
# Coordinates:
#   * time            (time) datetime64[ns] 1970-01-01 ... 1970-01-01T04:00:00....
# Dimensions without coordinates: grid_npoints
# Data variables:
#     deformed_bathy  (grid_npoints) float32 ...
#     longitude       (grid_npoints) float64 ...
#     latitude        (grid_npoints) float64 ...
#     min_height      (grid_npoints) float32 ...
#     max_height      (grid_npoints) float32 ...
#     eta             (time, grid_npoints) float32 ...
#     ux              (time, grid_npoints) float32 ...
#     uy              (time, grid_npoints) float32 ...
# Attributes: (12/416)
#     Conventions:                    CF-1.0
#     title:                          Time series output of Tsunami-HySEA model
#     Tsunami-HySEA_version:          3.8.1
#     creator_name:                   EDANYA Group
#     institution:                    University of Malaga
#     comments:                       No paper
#     ...                             ...
#     fault_384:                      time: 0.00, lon_barycenter: 22.48, lat_ba...
#     fault_385:                      time: 0.00, lon_barycenter: 22.77, lat_ba...
#     fault_386:                      time: 0.00, lon_barycenter: 23.57, lat_ba...
#     fault_387:                      time: 0.00, lon_barycenter: 23.40, lat_ba...
#     fault_388:                      time: 0.00, lon_barycenter: 22.65, lat_ba...
#     fault_389:                      time: 0.00, lon_barycenter: 22.46, lat_ba...

# %% [markdown]
# Map to see the offshore points and onshore grids

# %%
import folium
import folium.plugins

# Load the points file
data_pts = np.loadtxt('../../resources/raw/pois_eastern_sicily_2km.txt', dtype=str)
id_pts = data_pts[:, 0]
lon_pts = data_pts[:, 1].astype(float)
lat_pts = data_pts[:, 2].astype(float)
z_pts = data_pts[:, 3].astype(float)

ds_ts = xr.open_dataset(file_list[4]) #gridts file
ds_grids_CT = xr.open_dataset(file_list[1]) #gridts file
ds_grids_SR = xr.open_dataset(file_list[3]) #gridts file

# Create a Folium map centered on the data's extent
m = folium.Map(location=[np.mean(lat_pts),np.mean(lon_pts)], zoom_start=10,)

# Basemaps
folium.TileLayer(tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = False,
        control = True,
        show = False).add_to(m)

# Create a feature group for the offshore points 
fg_pts = folium.FeatureGroup(name='Offshore Points Txt').add_to(m)
fg_ptsNC = folium.FeatureGroup(name='Offshore Points NetCDF').add_to(m)
fg_gridnc_SR = folium.FeatureGroup(name='SR Grid NetCDF').add_to(m)
fg_gridnc_CT = folium.FeatureGroup(name='CT Grid NetCDF').add_to(m)

#add eq lat lon point
print(eve[eve_row])

# E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01673N3781_S005
lon = float(str(eve[eve_row]).split('_')[-2][1:5])/10
lat = float(str(eve[eve_row]).split('_')[-2][7:11])/100

folium.CircleMarker(location=[lat,lon],radius = 10,color='red',fill_color = 'red').add_to(m)

# Add a marker for each point with a tooltip showing its id
for id, lat, lon,z in zip(id_pts, lat_pts, lon_pts, z_pts):
    info = f"ID:{id}, Depth: {z} "  # Create tooltip string
    folium.Marker(location=[lat, lon],
                  tooltip=info,
                  icon=folium.Icon(color='blue', icon='')).add_to(fg_pts)

df_ts = pd.DataFrame({'lat':ds_ts.latitude.values.astype(float),
                      'lon':ds_ts.longitude.values.astype(float),
                      'z':ds_ts.deformed_bathy.values.astype(float)})

for i,row in df_ts.iterrows():
    info = f"ID:{i}, Depth: {row['z']} "  # Create tooltip string
    folium.CircleMarker(location=[row['lat'], row['lon']],
                  tooltip=info,radius=1,
                 icon=folium.Icon(color='red', icon='')).add_to(fg_ptsNC)

# Add grid netcdfs    
# data2plot = ds_grids_CT.isel(time=0)
# data = np.flipud(data2plot.max_height.values.astype(float))

# lon,lat = np.meshgrid(data2plot.lon.values.astype(float),
#                       data2plot.lat.values.astype(float))

# ext = [[lat.min(),lon.min()],
#          [lat.max(),lon.max()]]
# cm_function = matplotlib.cm.get_cmap('coolwarm')
# norm = (data - np.nanmin(data)) / (np.nanmax(data) - np.nanmin(data)) 

# folium.raster_layers.ImageOverlay(cm_function(norm),ext,opacity=0.5).add_to(fg_gridnc_CT)

# data2plot = ds_grids_SR.isel(time=0)
# data = np.flipud(data2plot.max_height.values.astype(float))

# lon,lat = np.meshgrid(data2plot.lon.values.astype(float),
#                       data2plot.lat.values.astype(float))

# ext = [[lat.min(),lon.min()],
#          [lat.max(),lon.max()]]

# norm = (data - np.nanmin(data)) / (np.nanmax(data) - np.nanmin(data)) 

# folium.raster_layers.ImageOverlay(cm_function(norm),ext,opacity=0.5,interactive=True).add_to(fg_gridnc_SR)



# # Add a layer control to turn on/off the feature groups
# folium.LayerControl().add_to(m)
# folium.plugins.MousePosition().add_to(m)

#save as html
# m.save('./../resources/gis/html/event_example.html')

m
# Out:
# PS_manning003/E02020N3739E02658N3366-PS-Str_PYes_Hom-M850_E02272N3440_S000
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f6acdf0fedca6db0516f93fc49aff02 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f6acdf0fedca6db0516f93fc49aff02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f6acdf0fedca6db0516f93fc49aff02 = L.map(
#                 &quot;map_9f6acdf0fedca6db0516f93fc49aff02&quot;,
#                 {
#                     center: [37.36126910344827, 15.281493436781608],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6d86d5d41865e6a21933d7cae8b4fd3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f6acdf0fedca6db0516f93fc49aff02);
#
#
#             var tile_layer_19ae92e0c4a15a997fca6362392bed5b = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: &quot;Esri&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9f6acdf0fedca6db0516f93fc49aff02);
#
#
#             var feature_group_21c2302a40924b869e58c7f7393fa147 = L.featureGroup(
#                 {}
#             ).addTo(map_9f6acdf0fedca6db0516f93fc49aff02);
#
#
#             var marker_e9d716035d5e5e260b37966440deaec5 = L.marker(
#                 [38.320504, 15.566667],
#                 {}
#             ).addTo(feature_group_21c2302a40924b869e58c7f7393fa147);
#
#
#             var icon_dbbbc797dca8eae7faff5eb9d3897870 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e9d716035d5e5e260b37966440deaec5.setIcon(icon_dbbbc797dca8eae7faff5eb9d3897870);
#
#
#             marker_e9d716035d5e5e260b37966440deaec5.bindTooltip(
#                 `&lt;div&gt;
#                      ID:9112, Depth: -36.1808
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f0c789603c74c0413a29242317fbe00a = L.marker(
#                 [38.308333, 15.582796],
#                 {}
#             ).addTo(feature_group_21c2302a40924b869e58c7f7393fa147);
#
#
#             var icon_e7f29c96832a4e86dbf9d7167f1b35ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f0c789603c74c0413a29242317fbe00a.setIcon(icon_e7f29c96832a4e86dbf9d7167f1b35ba);
#
#
#             marker_f0c789603c74c0413a29242317fbe00a.bindTooltip(
#                 `&lt;div&gt;
#                      ID:9113, Depth: -51.6129
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdcda6a7225ea5142dce1e0ff45fc034 = L.marker(
#                 [38.293459, 15.6],
#                 {}
#             ).addTo(feature_group_21c2302a40924b869e58c7f7393fa147);
#
#
#             var icon_b5683d9c515d60c87907dfdee1678853 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bdcda6a7225ea5142dce1e0ff45fc034.setIcon(icon_b5683d9c515d60c87907dfdee1678853);
#
#
#             marker_bdcda6a7225ea5142dce1e0ff45fc034.bindTooltip(
#                 `&lt;div&gt;
#                      ID:9114, Depth: -43.6648
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5b551f535372f0dd5112c2b46bb790dd = L.marker(
#                 [38.283333, 15.61817],
#                 {}
#             ).addTo(feature_group_21c2302a40924b869e58c7f7393fa147);
#
#
#             var icon_9bae8579bd7b1bc3cf86b54ab7a31c84 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5b551f535372f0dd5112c2b46bb790dd.setIcon(icon_9bae8579bd7b1bc3cf86b54ab7a31c84);
#
#
#             marker_5b

# %% [markdown]
# Offshore time series

# %%
ds = xr.open_dataset(file_list[-1]) #offshore ts file
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:         (grid_npoints: 87, time: 481)
# Coordinates:
#   * time            (time) datetime64[ns] 1970-01-01 ... 1970-01-01T04:00:00....
# Dimensions without coordinates: grid_npoints
# Data variables:
#     deformed_bathy  (grid_npoints) float32 ...
#     longitude       (grid_npoints) float64 ...
#     latitude        (grid_npoints) float64 ...
#     min_height      (grid_npoints) float32 ...
#     max_height      (grid_npoints) float32 ...
#     eta             (time, grid_npoints) float32 ...
#     ux              (time, grid_npoints) float32 ...
#     uy              (time, grid_npoints) float32 ...
# Attributes: (12/416)
#     Conventions:                    CF-1.0
#     title:                          Time series output of Tsunami-HySEA model
#     Tsunami-HySEA_version:          3.8.1
#     creator_name:                   EDANYA Group
#     institution:                    University of Malaga
#     comments:                       No paper
#     ...                             ...
#     fault_384:                      time: 0.00, lon_barycenter: 22.48, lat_ba...
#     fault_385:                      time: 0.00, lon_barycenter: 22.77, lat_ba...
#     fault_386:                      time: 0.00, lon_barycenter: 23.57, lat_ba...
#     fault_387:                      time: 0.00, lon_barycenter: 23.40, lat_ba...
#     fault_388:                      time: 0.00, lon_barycenter: 22.65, lat_ba...
#     fault_389:                      time: 0.00, lon_barycenter: 22.46, lat_ba...

# %% [markdown]
# Plot each location time series 53:58 for Siracusa and 35:44 for Catania in each subplot

# %%
fig, ax = plt.subplots(1, 2, figsize=(25, 7))

for i in range(35,45):
    ax[0].plot(ds.time,ds.eta[:,i],label = f'loc:{i}')
ax[0].set_title(f'Locations Catania:35:44')
ax[0].set_label
ax[0].legend()


for i in range(53,59):
    ax[1].plot(ds.time,ds.eta[:,i],label = f'loc:{i}')
ax[1].set_title(f'Locations Siracusa:53:58')
ax[1].legend()

plt.show()

fig, ax = plt.subplots(1, 1, figsize=(25, 7))
for i in range(0,2):
    ax.plot(ds.time,ds.eta[:,i],label = f'loc:{i}')
ax.set_title(f'Locations ')
ax.legend()
#add tick every 10mins
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
plt.show()

# %%
plt.figure(figsize=(15, 7))
plt.plot(ds.time,ds.eta[:,4],label = f'loc:{57}')
plt.grid(which = 'major')

# %% [markdown]
# Depth at offshore points

# %%
ds.deformed_bathy.plot(label = 'deformed_bathy')
plt.plot(z_pts*-1,label = 'offshore points org depth')
plt.legend()
plt.show()

# %% [markdown]
# Had to rename some file names which had some the event id joined to it

# %%
# file_list = glob.glob('./../data/simu/PS_manning003/**/*SR_defbathy.nc')
# print(len(file_list))
# with open ('SR_rename.txt', 'w') as file:
#     for idx, item in enumerate (file_list):
#         file.write(',')
#         file.write(item)


# for file in file_list:
#     # print(file)
#     # print(os.path.join(file.rsplit('/',1)[-2],'SR_defbathy.nc'))
#     os.rename(file,os.path.join(file.rsplit('/',1)[-2],'SR_defbathy.nc'))

# %% [markdown]
# Grid Data

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature

ds_grids_CT = xr.open_dataset(file_list[4]) #gridts file
ds_grids_SR = xr.open_dataset(file_list[5]) #gridts file

# print(ds_grids_CT)
# print(ds_grids_SR)

#plot maps of max height and deformations
fig,ax = plt.subplots(2,2,figsize=(18,15), subplot_kw={'projection': ccrs.PlateCarree()})
plt.figtext(0.5,0.9,'CT')
plt.figtext(0.5,0.5,'SR')

ds_grids_CT.max_height.plot(ax=ax[0,1],)
ds_grids_CT.deformation.plot(ax=ax[0,0])
ds_grids_SR.max_height.plot(ax=ax[1,1])
ds_grids_SR.deformation.plot(ax=ax[1,0])
coast = cfeature.GSHHSFeature(scale='full')

for i in range(2):
    for j in range(2):
        ax[i,j].add_feature(coast, edgecolor='black')
        ax[i,j].gridlines(draw_labels=True, dms=True, x_inline=False, y_inline=False)

plt.show()

# %% [markdown]
# Try to mask use deformed bathy and plot only onshore values

# %%
ds_Z = xr.open_dataset(file_list[6]) #gridts file
ds_dZ = xr.open_dataset(file_list[7]) #gridts file
ds_D = xr.open_dataset(file_list[8]) #gridts file
ds_H = xr.open_dataset(file_list[9]) #gridts file

# print(ds_Z.z.max())
# ds_Z.z.plot()
# plt.show()
# print(ds_dZ.deformation.max())
# ds_dZ.deformation.plot()
# plt.show()
# ds_D.z.plot()
# print(ds_D.z.max())
# plt.show()

ds_H.max_height.plot()
print(ds_H.max_height.max())
plt.show()

ds_H.max_height.where(ds_Z.z.values > 0).plot()
plt.show()

i = 700
j = 600

z = ds_Z.z[i,j].values.astype(float)
dZ = ds_dZ.deformation[i,j].values.astype(float)
D = ds_D.z[i,j].values.astype(float)
H = ds_H.max_height[i,j].values.astype(float)

print('z,dZ,D,H',z,dZ,D,H)

print('check if h = z+D here',z+D)

print('if we remove dZ from all variable for ML training',dZ)
# Out:
# <xarray.DataArray 'max_height' ()>
# array(7.6737633, dtype=float32)
# z,dZ,D,H 1.234675407409668 0.037384603172540665 0.23782062530517578 1.4724960327148438
# check if h = z+D here 1.4724960327148438
# if we remove dZ from all variable for ML training 0.037384603172540665

# %%
ds_Z = xr.open_dataset(file_list[6]) #gridts file
ds_dZ = xr.open_dataset(file_list[7]) #gridts file
ds_D = xr.open_dataset(file_list[8]) #gridts file
ds_H = xr.open_dataset(file_list[9]) #gridts file

# print(ds_Z.z.max())
# ds_Z.z.plot()
# plt.show()
print(ds_dZ.deformation.max())
ds_dZ.deformation.plot()
plt.show()
# ds_D.z.plot()
# print(ds_D.z.max())
# plt.show()
# ds_H.max_height.plot.contourf()
# print(ds_H.max_height.max())
# plt.show()

var = ds_Z.z
var = var.where(var > 0)
var.plot()
plt.show()

i = 700
j = 600

z = ds_Z.z[i,j].values.astype(float)
dZ = ds_dZ.deformation[i,j].values.astype(float)
D = ds_D.z[i,j].values.astype(float)
H = ds_H.max_height[i,j].values.astype(float)

print('z,dZ,D,H',z,dZ,D,H)

print('check if h = z+D here',z+D)

print('if we remove dZ from all variable for ML training',dZ)
# Out:
# <xarray.DataArray 'deformation' ()>
# array(0.0389105, dtype=float32)
# z,dZ,D,H 1.234675407409668 0.037384603172540665 0.23782062530517578 1.4724960327148438
# check if h = z+D here 1.4724960327148438
# if we remove dZ from all variable for ML training 0.037384603172540665

# %% [markdown]
# Calculate Statistics from offshore gauges and onshore grids

# %%
regions = ['CT','SR']

#gauge variables: time,eta,depth,velocity
features_name = ['id','count','max','logsum','mean','sd']
all_eve_df_CT = pd.DataFrame(columns = features_name)
all_eve_df_SR = pd.DataFrame(columns = features_name)
offshore_maxh = pd.DataFrame()

#output destination for summary statistics
OnshorePath = './../data/info/C_{:s}_alleve{:s}.onshore.txt'
OffshorePath ='./../data/info/grid0_allpts{:s}_alleve{:s}.offshore.txt'

#read station data for each event and calculate statistics for each gauge
for i,e in enumerate(eve):
    print('processing',i,'of',len(eve),e,end='\r')
    #offshore
    Tpath_format = sim_dir + e + '/grid0_ts.nc'
    TS_pts = xr.open_dataset(Tpath_format) #ts file of offshore points
    offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
                            columns=[e])

    #onshore
    Hpath_format = sim_dir + e + '/C_{:s}.nc'
    Zpath_format = sim_dir + e + '/{:s}_defbathy.nc'
    Opath_format = sim_dir + e + '/C_{:s}.nc.onshore.txt'

    eve_df = pd.DataFrame(columns = features_name)
    for reg in regions:
        H_grids = xr.open_dataset(Hpath_format.format(reg)) #grid file of depth
        Z_grids = xr.open_dataset(Zpath_format.format(reg)) #grid file of bathymetry

        H = H_grids.max_height
        Z = Z_grids.z.values
        H = H.where(Z > 0)
        
        df=[e,H.count().values.astype(int),
         H.max().values.astype(float).round(2),
         np.log(H.sum().values.astype(float)+1).round(2),
         H.mean().values.astype(float).round(2),
         H.std().values.astype(float).round(2)]
        
        df = pd.DataFrame(df).T
        df.columns = features_name

        eve_df = pd.concat([eve_df,df])
        eve_df.to_csv(Opath_format.format(reg),index=False,sep='\t')
        eve_df = pd.DataFrame(columns = features_name)

        if reg == 'CT':
            all_eve_df_CT = pd.concat([all_eve_df_CT,df])
        elif reg =='SR':
            all_eve_df_SR = pd.concat([all_eve_df_SR,df])
        else:
            print('error')
            
#write summary statistics to file - onshore
all_eve_df_CT.to_csv(OnshorePath.format('CT',str(all_eve_df_CT.shape[0])),index=False,sep='\t')
all_eve_df_SR.to_csv(OnshorePath.format('SR',str(all_eve_df_SR.shape[0])),index=False,sep='\t')
#write summary statistics to file - offshore
offshore_maxh = offshore_maxh.T
offshore_maxh.index.name = 'id'
offshore_maxh.to_csv(OffshorePath.format(str(offshore_maxh.shape[1]),str(offshore_maxh.shape[0])),index=True,sep='\t')
# Out:
# processing 100 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M861_E02247N3453_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 101 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M809_E01655N3704_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 102 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02268N3554_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 103 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02218N3525_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 104 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02337N3493_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 105 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M861_E02094N3692_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 106 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01689N3734_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 107 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M861_E02144N3587_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 108 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01670N3819_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 109 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02243N3539_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 110 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M871_E02144N3587_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 111 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M902_E02337N3493_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 112 of 1212 E02113N3823E02873N3483-PS-Mur_PNo_Hom-M871_E02308N3607_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 113 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01720N3803_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 114 of 1212 E01577N3897E01966N3571-PS-Str_PYes_Hom-M861_E01774N3710_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 115 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01697N3782_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 116 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M861_E02305N3524_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 117 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M871_E02237N3564_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 118 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M902_E02313N3510_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 119 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M888_E02526N3441_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 120 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01701N3725_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 121 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M861_E02260N3540_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 122 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01783N3758_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 123 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02168N3560_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 124 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01734N3775_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 125 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02253N3527_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 126 of 1212 E01849N3766E02950N3220-PS-Mur_PYes_Var-M861_E02054N3653_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 127 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M880_E02152N3603_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 128 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M871_E02122N3652_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 129 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02253N3503_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 130 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01723N3765_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 131 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M895_E02270N3502_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 132 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02335N3468_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 133 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M888_E02434N3452_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 134 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M850_E01727N3708_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 135 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M871_E02219N3560_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 136 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01710N3774_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 137 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02393N3468_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 138 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M861_E02201N3596_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 139 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02206N3569_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 140 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02311N3485_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 141 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02321N3496_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 142 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02217N3548_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 143 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02284N3476_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 144 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M880_E02287N3501_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 145 of 1212 E01849N3766E02950N3220-PS-Str_PYes_Hom-M871_E02072N3658_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 146 of 1212 E02113N3823E02873N3483-PS-Str_PNo_Hom-M861_E02435N3522_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 147 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M888_E02328N3482_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 148 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01732N3794_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 149 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02393N3468_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 150 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02253N3503_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 151 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M809_E01760N3738_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 152 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M871_E02152N3645_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 153 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02229N3514_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 154 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01721N3784_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 155 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02183N3593_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 156 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02301N3474_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 157 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01684N3791_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 158 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M880_E02188N3566_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 159 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02217N3548_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 160 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01670N3819_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 161 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M895_E02458N3438_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 162 of 1212 E01964N3926E02184N3685-PS-Mur_PYes_Hom-M754_E02050N3785_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 163 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02478N3458_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 164 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M861_E02189N3468_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 165 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M880_E02120N3675_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 166 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01695N3801_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 167 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M861_E02326N3457_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 168 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02318N3471_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 169 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02168N3560_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 170 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01731N3813_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 171 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01727N3708_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 172 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02344N3478_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 173 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M888_E02144N3587_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 174 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M888_E02321N3496_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 175 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M871_E02183N3593_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 176 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M732_E01735N3756_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 177 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M871_E02122N3652_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 178 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M895_E02217N3548_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 179 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01677N3724_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 180 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M880_E02253N3481_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 181 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M888_E02458N3438_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 182 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M888_E02184N3552_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 183 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M895_E02242N3492_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 184 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M861_E02166N3518_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 185 of 1212 E01577N3897E01966N3571-PS-Str_PYes_Var-M861_E01739N3699_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 186 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02368N3461_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 187 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M871_E02253N3503_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 188 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01714N3716_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 189 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01734N3775_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 190 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M888_E02279N3514_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 191 of 1212 E01548N3896E01854N3659-PS-Mur_PYes_Hom-M754_E01668N3695_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 192 of 1212 E01577N3897E01966N3571-PS-Str_PYes_Var-M861_E01750N3709_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 193 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01700N3744_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 194 of 1212 E02113N3823E02873N3483-PS-Str_PYes_Var-M809_E02209N3683_S000
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 195 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Hom-M888_E02393N3468_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 196 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02229N3514_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 197 of 1212 E01577N3897E01966N3571-PS-Str_PYes_Var-M850_E01774N3710_S000
# ...
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1180 of 1212 E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01694N3821_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1181 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M880_E02260N3491_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1182 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02188N3566_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1183 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M902_E02287N3526_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1184 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02236N3526_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1185 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M895_E02311N3485_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1186 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M902_E02409N3467_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1187 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02232N3550_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1188 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M895_E02361N3475_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1189 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02188N3566_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1190 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02351N3465_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1191 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02226N3538_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1192 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02201N3524_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1193 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02194N3581_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1194 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02417N3454_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1195 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02159N3618_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1196 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M888_E02152N3603_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1197 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M895_E02270N3502_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1198 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02296N3512_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1199 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02318N3471_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1200 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02206N3569_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1201 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Hom-M895_E02351N3465_S005
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1202 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02184N3552_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1203 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M888_E02284N3476_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1204 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02294N3487_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1205 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M902_E02270N3527_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1206 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02189N3538_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1207 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02184N3552_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1208 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02368N3461_S004
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1209 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M888_E02301N3474_S001
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1210 of 1212 E02020N3739E02658N3366-PS-Mur_PYes_Var-M895_E02467N3448_S002
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),
# processing 1211 of 1212 E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02335N3468_S003
# /tmp/ipykernel_2446553/129085788.py:19: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   offshore_maxh[e] = pd.DataFrame(TS_pts.eta.max(dim='time').values.astype(float).round(2),

# %% [markdown]
# Some quick plots about overall dataset

# %%
all_eve_df_PS = pd.read_csv('/mnt/data/nragu/Tsunami/INGV/IUSS_INGV_Repo/resources/processed/eve_PS.txt',sep='\t')

#pick meta info for each event
about_eve = all_eve_df_PS[all_eve_df_PS['ID'].isin(eve)]
about_eve = about_eve.set_index('ID')
about_eve = about_eve.reindex(eve)
about_eve = about_eve.reset_index()
#save selected meta info
about_eve.to_csv('./../data/info/about_alleve{:s}_PS.txt'.format(str(about_eve.shape[0])),index=False,sep='\t')

# %%
all_eve_df_CT = pd.read_csv('/mnt/data/nragu/Tsunami/INGV/IUSS_INGV_Repo/data/info/C_CT_alleve1212.onshore.txt',sep='\t')
all_eve_df_SR = pd.read_csv('/mnt/data/nragu/Tsunami/INGV/IUSS_INGV_Repo/data/info/C_SR_alleve1212.onshore.txt',sep='\t')
offshore_maxh = pd.read_csv('/mnt/data/nragu/Tsunami/INGV/IUSS_INGV_Repo/data/info/grid0_allpts87_alleve1212.offshore.txt',sep='\t')
about_eve = pd.read_csv('/mnt/data/nragu/Tsunami/INGV/IUSS_INGV_Repo/data/info/about_alleve1212_PS.txt',sep='\t')

#plotting
# plt.plot(about_eve['Mag'],all_eve_df_CT['max'],'o',alpha = 0.5,label='CT')
# plt.plot(about_eve['Mag'],all_eve_df_SR['max'],'o',alpha = 0.5,label='SR')
# plt.show()

# plt.hist(all_eve_df_CT['max'])
plt.hist(all_eve_df_SR['count'])
# Out:
# (array([311.,  95., 121., 115., 111., 185., 135., 102.,  31.,   6.]),
#  array([  408.,  6424., 12440., 18456., 24472., 30488., 36504., 42520.,
#         48536., 54552., 60568.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# Pick events by some filter and plot

# %%
#top 10 % of max depth at CT
ids = all_eve_df_CT[all_eve_df_CT['count'] > all_eve_df_CT['count'].quantile(q=0.9)].id
# ids = all_eve_df_SR[all_eve_df_SR['count'] > all_eve_df_SR['count'].quantile(q=0.9)].id

sample_events = about_eve[about_eve['ID'].isin(ids)]


# Create a Folium map centered on the data's extent
newm = folium.Map(location=[np.mean(about_eve['Lat']), np.mean(about_eve['Long'])], zoom_start=7)

sample_events['pop'] = sample_events['ID'] + '_' + sample_events['Mag'].astype(str)

ncallback = ('function (row) {' 
                'var marker = L.marker(new L.LatLng(row[0], row[1]), {color: "red"});'
                'var icon = L.AwesomeMarkers.icon({'
                "icon: 'info-sign',"
                "iconColor: 'white',"
                "markerColor: 'red',"
                "prefix: 'glyphicon',"
                "extraClasses: 'fa-rotate-0'"
                    '});'
                'marker.setIcon(icon);'
                "var popup = L.popup({maxWidth: '500'});"
                "const display_text = {text: row[2]};"
                "var mytext = $(`<div id='mytext' class='display_text' style='width: 100.0%; height: 100.0%;'> ${display_text.text}</div>`)[0];"
                "popup.setContent(mytext);"
                "marker.bindPopup(popup);"
                'return marker};')

fg_select = folium.FeatureGroup(name='Offshore Points Txt').add_to(newm)

folium.plugins.FastMarkerCluster(sample_events[['Lat','Long','pop']].
                  values.tolist(), callback=ncallback,name='EQ Events by filter').add_to(fg_select)

# Add a layer control to turn on/off the feature groups
folium.LayerControl().add_to(newm)
folium.plugins.MousePosition().add_to(newm)

newm
# Out:
# /tmp/ipykernel_2446553/2386895572.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_events['pop'] = sample_events['ID'] + '_' + sample_events['Mag'].astype(str)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bdb753e82a3c27d2087a43f6060382b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bdb753e82a3c27d2087a43f6060382b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5bdb753e82a3c27d2087a43f6060382b = L.map(
#                 &quot;map_5bdb753e82a3c27d2087a43f6060382b&quot;,
#                 {
#                     center: [36.11480198019802, 21.046633663366336],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ec0d7215e15033da29d9696e05253a6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5bdb753e82a3c27d2087a43f6060382b);
#
#
#             var feature_group_e8a7456864f8d36bcc7d87e9f94060f0 = L.featureGroup(
#                 {}
#             ).addTo(map_5bdb753e82a3c27d2087a43f6060382b);
#
#
#             var fast_marker_cluster_5262689d1fc3425dcc73bfd344057037 = (function(){
#                 var callback = function (row) {var marker = L.marker(new L.LatLng(row[0], row[1]), {color: &quot;red&quot;});var icon = L.AwesomeMarkers.icon({icon: &#x27;info-sign&#x27;,iconColor: &#x27;white&#x27;,markerColor: &#x27;red&#x27;,prefix: &#x27;glyphicon&#x27;,extraClasses: &#x27;fa-rotate-0&#x27;});marker.setIcon(icon);var popup = L.popup({maxWidth: &#x27;500&#x27;});const display_text = {text: row[2]};var mytext = $(`&lt;div id=&#x27;mytext&#x27; class=&#x27;display_text&#x27; style=&#x27;width: 100.0%; height: 100.0%;&#x27;&gt; ${display_text.text}&lt;/div&gt;`)[0];popup.setContent(mytext);marker.bindPopup(popup);return marker};;
#
#                 var data = [[38.14, 17.55, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01755N3814_S004_8.61&quot;], [35.38, 22.26, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02226N3538_S004_9.02&quot;], [37.72, 16.86, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01686N3772_S005_8.61&quot;], [37.84, 17.21, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01721N3784_S001_8.61&quot;], [38.1, 16.83, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01683N3810_S003_8.61&quot;], [37.65, 17.23, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01723N3765_S002_8.61&quot;], [38.24, 17.66, &quot;E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01766N3824_S005_8.61&quot;], [34.51, 23.59, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02359N3451_S001_8.95&quot;], [37.38, 17.6, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01760N3738_S001_8.61&quot;], [35.15, 22.45, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02245N3515_S001_9.02&quot;], [37.54, 17.11, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01711N3754_S003_8.61&quot;], [34.39, 24.41, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02441N3439_S005_9.02&quot;], [37.06, 17.03, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01703N3706_S005_8.61&quot;], [37.96, 17.8, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01780N3796_S001_8.61&quot;], [35.66, 21.88, &quot;E02020N3739E02658N3366-PS-Str_PYes_Hom-M902_E02188N3566_S003_9.02&quot;], [37.25, 17.01, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01701N3725_S005_8.61&quot;], [38.21, 16.94, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01694N3821_S002_8.61&quot;], [37.09, 17.5, &quot;E01577N3897E01966N3571-PS-Str_PYes_Var-M861_E01750N3709_S001_8.61&quot;], [37.48, 17.72, &quot;E01548N3896E01854N3659-PS-Str_PYes_Hom-M861_E01772N3748_S001_8.61&quot;], [34.93, 23.37, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M895_E02337N3493_S002_8.95&quot;], [38.19, 16.7, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01670N3819_S001_8.61&quot;], [37.82, 16.97, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01697N3782_S004_8.61&quot;], [35.1, 23.13, &quot;E02020N3739E02658N3366-PS-Mur_PYes_Hom-M902_E02313N3510_S001_9.02&quot;], [37.65, 17.23, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M861_E01723N3765_S005_8.61&quot;], [35.69, 22.06, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02206N3569_S002_9.02&quot;], [34.68, 23.93, &quot;E02020N3739E02658N3366-PS-Str_PYes_Var-M902_E02393N3468_S001_9.02&quot;], [37.84, 17.21, &quot;E01548N3896E01854N3659-PS-Str_PYes_Var-M8
